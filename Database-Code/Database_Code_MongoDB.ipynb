# %%
pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 29.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 23.6 MB/s eta 0:00:00
# ...

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://kartikgm0101:kartik@intellewings.enj2zjz.mongodb.net/?retryWrites=true&w=majority&appName=Intellewings"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
import pandas as pd

# %%
#SEBI data upload to database

# %%
csv_path = "/content/Final_data_SEBI_without_cin_new.csv"  # Update path if needed
df = pd.read_csv(csv_path)
df = df.fillna("")  # Replace NaN with empty string
data = df.to_dict(orient="records")

# %%
db = client["sebi_data"]             # This is the database name
collection = db["data"]             # You can name collection anything

collection.insert_many(data)
print("✅ Data uploaded to MongoDB Atlas!")
# Out:
# ✅ Data uploaded to MongoDB Atlas!

# %%
#IOSCO data upload to database

# %%
csv_path = "/content/iosco_combined (1) (1).csv"  # Update path if needed
df = pd.read_csv(csv_path)
df = df.fillna("")  # Replace NaN with empty string
data = df.to_dict(orient="records")

db_name = "iosco_data"        # Change as per CSV
collection_name = "notices"  # Change as per CSV

# ⬆️ Upload
db = client[db_name]
collection = db[collection_name]
collection.insert_many(data)

print(f"✅ Data uploaded to MongoDB Atlas! [{db_name}.{collection_name}]")
# Out:
# ✅ Data uploaded to MongoDB Atlas! [iosco_data.notices]

# %%
#Interpol data upload to database with duplicated

# %%
csv_path = "/content/combined_interpol_data_new (1).csv"  # Update path if needed
df = pd.read_csv(csv_path)
df = df.fillna("")  # Replace NaN with empty string
data = df.to_dict(orient="records")

db_name = "interpol_data_with_duplicates"         # ✅ Updated database name for Interpol
collection_name = "notices"       # ✅ Collection for Interpol notices

# ⬆️ Upload
db = client[db_name]
collection = db[collection_name]
collection.insert_many(data)

print(f"✅ Data uploaded to MongoDB Atlas! [{db_name}.{collection_name}]")
# Out:
# ✅ Data uploaded to MongoDB Atlas! [interpol_data_with_duplicates.notices]

# %%
#Interpol data upload to database non duplicated

# %%
csv_path = "/content/Interpol_non_duplicated_new.csv"  # Update path if needed
df = pd.read_csv(csv_path)
df = df.fillna("")  # Replace NaN with empty string
data = df.to_dict(orient="records")

db_name = "interpol_data_cleaned"         # ✅ Updated database name for Interpol
collection_name = "notices2"       # ✅ Collection for Interpol notices

# ⬆️ Upload
db = client[db_name]
collection = db[collection_name]
collection.insert_many(data)

print(f"✅ Data uploaded to MongoDB Atlas! [{db_name}.{collection_name}]")
# Out:
# ✅ Data uploaded to MongoDB Atlas! [interpol_data_cleaned.notices2]

# %%
from pymongo import MongoClient

# Connect to MongoDB Atlas (guest access)
client = MongoClient("mongodb+srv://guest:guest_pass@intellewings.enj2zjz.mongodb.net/?retryWrites=true&w=majority&appName=Intellewings")

# Select the database and collection
db = client["iosco_data"]
collection = db["notices"]
# Fetch and print all documents
docs = collection.find()
for doc in docs:
    print(doc)
# Out:
# {'_id': ObjectId('688e68650a06a5cf2da46c5f'), 'Name_company': 'Facebook page “Oh Juice ฟาร์มออร์แกนิก”', 'Corporate Name': '', 'site_url': 'https://www.facebook.com/profile.php?id=100093642284232', 'Authority_Name': 'Thailand - Securities and Exchange Commission', 'Authority_link': 'https://web-invpublic.sec.or.th/e/2808/2568', 'date': '2025-08-01', 'id': 39795, 'Warning ID': 39795.0, 'NCA': '', 'Date Published At NCA': '2025-08-01', 'Date Published At IOSCO': '2025-08-01', 'Last Updated': '2025-08-01', 'NCA URL': 'https://web-invpublic.sec.or.th/e/2808/2568', 'Commercial Name': 'Facebook page “Oh Juice ฟาร์มออร์แกนิก”', 'URL': 'https://www.facebook.com/profile.php?id=100093642284232', 'Other URL': 'https://www.facebook.com/100093642284232/videos/1253830625885527', 'Category': 'Other', 'Additional Information': 'This account is not affiliated with any businesses licensed or regulated by the SEC Thailand. Kindly be cautious with your investments.'}
# ...
