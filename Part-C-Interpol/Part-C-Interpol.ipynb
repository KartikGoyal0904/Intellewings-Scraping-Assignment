# %%
import pandas as pd
df=pd.read_csv("/content/Interpol_Countries_with_Codes_Corrected.csv")

# %%
lis=df["Country Code"]
len(lis)
# Out:
# 193

# %%
import requests
import math
import pandas as pd
import time
import os

# === Setup ===
BASE_URL = "https://ws-public.interpol.int/notices/v1/red"
HEADERS = {"User-Agent": "Mozilla/5.0 (X11; Linux x86_64)"}
COUNTRY_FILE = "/content/Interpol_Countries_with_Codes_Corrected.csv"

# === Delay Configuration ===
PAGE_DELAY = 1.5
RETRY_DELAY = 3
MAX_RETRIES = 3

# === Load country code mappings ===
country_df = pd.read_csv(COUNTRY_FILE)
code_to_country = dict(zip(country_df['Country Code'].str.strip(), country_df['Country'].str.strip()))

# === Country Codes Input ===
selected_country_codes = lis

# === Request Functions ===
def get_notices_page(page: int, country_code: str):
    url = f"{BASE_URL}?nationality={country_code}&page={page}&resultPerPage=20"
    for attempt in range(MAX_RETRIES):
        try:
            response = requests.get(url, headers=HEADERS, timeout=10)
            if response.status_code == 200 and "application/json" in response.headers.get("Content-Type", ""):
                return response.json()
            else:
                print(f"⚠️ Status {response.status_code} for {url}")
        except Exception as e:
            print(f"🔁 Retry {attempt+1}/{MAX_RETRIES} - Error fetching page {page}: {e}")
            time.sleep(RETRY_DELAY)
    return None

def get_self_data(self_link: str):
    for attempt in range(MAX_RETRIES):
        try:
            response = requests.get(self_link, headers=HEADERS, timeout=10)
            if response.status_code == 200 and "application/json" in response.headers.get("Content-Type", ""):
                return response.json()
        except Exception as e:
            print(f"🔁 Retry {attempt+1}/{MAX_RETRIES} - Error fetching self data: {e}")
            time.sleep(RETRY_DELAY)
    return {}

# === Extract + Transform ===
def extract_combined_data(notice: dict, detail: dict):
    arrest_warrant = detail.get("arrest_warrants", [{}])[0] if detail.get("arrest_warrants") else {}

    def get_country_name(code):
        return code_to_country.get(code, code)

    return {
        "entity_id": notice.get("entity_id", None),
        "forename": notice.get("forename", None),
        "name": notice.get("name", None),
        "date_of_birth": notice.get("date_of_birth", None),
        "nationalities": ", ".join(notice.get("nationalities", [])) if notice.get("nationalities") else None,
        "thumbnail": notice["_links"].get("thumbnail", {}).get("href", None),
        "images": notice["_links"].get("images", {}).get("href", None),
        "self_link": notice["_links"].get("self", {}).get("href", None),

        # Self-link fields
        "sex_id": detail.get("sex_id", None),
        "place_of_birth": detail.get("place_of_birth", None),
        "country_of_birth": get_country_name(detail.get("country_of_birth_id", None)),
        "eyes_colors_id": detail.get("eyes_colors_id", None),
        "hairs_id": detail.get("hairs_id", None),
        "height": detail.get("height", None),
        "weight": detail.get("weight", None),
        "languages_spoken_ids": ", ".join(detail.get("languages_spoken_ids", [])) if detail.get("languages_spoken_ids") else None,
        "distinguishing_marks": detail.get("distinguishing_marks", None),
        "arrest_charge": arrest_warrant.get("charge", None),
        "arrest_issuing_country": get_country_name(arrest_warrant.get("issuing_country_id", None)),
        "arrest_charge_translation": arrest_warrant.get("charge_translation", None)
    }

# === Loop through Selected Country Codes ===
for country_code in selected_country_codes:
    print(f"\n==================== {country_code} ====================")
    OUTPUT_DIR = os.path.join(os.getcwd(), country_code)
    os.makedirs(OUTPUT_DIR, exist_ok=True)

    CHECKPOINT_FILE = os.path.join(OUTPUT_DIR, f"{country_code}_checkpoint.csv")
    FINAL_OUTPUT_FILE = os.path.join(OUTPUT_DIR, f"{country_code}_combined_data.csv")

    all_data = []

    # Step 1: Get first page
    first_page = get_notices_page(1, country_code)
    if not first_page:
        print(f"❌ Failed to fetch first page for {country_code}. Skipping...")
        continue

    total_notices = first_page.get("total", 0)
    if total_notices == 0:
        print(f"⚠️ No notices found for {country_code}. Skipping...")
        continue

    total_pages = math.ceil(total_notices / 20)
    print(f"🔍 {total_notices} notices, {total_pages} pages for {country_code}")

    # Step 2: Scrape all pages
    for page in range(1, total_pages + 1):
        print(f"📄 Fetching page {page}/{total_pages} for {country_code}")
        page_data = get_notices_page(page, country_code)
        if not page_data:
            print(f"⚠️ Skipping page {page}")
            continue

        notices = page_data.get("_embedded", {}).get("notices", [])
        for notice in notices:
            self_link = notice["_links"]["self"]["href"]
            detail = get_self_data(self_link)
            record = extract_combined_data(notice, detail)
            all_data.append(record)

        # Save checkpoint after each page
        pd.DataFrame(all_data).to_csv(CHECKPOINT_FILE, index=False)
        print(f"💾 Checkpoint saved (Page {page})")
        time.sleep(PAGE_DELAY)

    # Step 3: Final save
    pd.DataFrame(all_data).to_csv(FINAL_OUTPUT_FILE, index=False)
    print(f"✅ Final saved at: {FINAL_OUTPUT_FILE}")
# Out:
# ==================== DZ ====================
# 🔍 18 notices, 1 pages for DZ
# 📄 Fetching page 1/1 for DZ
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/DZ/DZ_combined_data.csv
#
# ==================== AO ====================
# 🔍 7 notices, 1 pages for AO
# 📄 Fetching page 1/1 for AO
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/AO/AO_combined_data.csv
#
# ==================== BJ ====================
# ⚠️ No notices found for BJ. Skipping...
#
# ==================== BW ====================
# ⚠️ No notices found for BW. Skipping...
#
# ==================== BF ====================
# ⚠️ No notices found for BF. Skipping...
#
# ==================== BI ====================
# 🔍 2 notices, 1 pages for BI
# 📄 Fetching page 1/1 for BI
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/BI/BI_combined_data.csv
#
# ==================== CV ====================
# ⚠️ No notices found for CV. Skipping...
#
# ==================== CM ====================
# 🔍 2 notices, 1 pages for CM
# 📄 Fetching page 1/1 for CM
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/CM/CM_combined_data.csv
#
# ==================== CF ====================
# 🔍 4 notices, 1 pages for CF
# 📄 Fetching page 1/1 for CF
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/CF/CF_combined_data.csv
#
# ==================== TD ====================
# ⚠️ No notices found for TD. Skipping...
#
# ==================== KM ====================
# ⚠️ No notices found for KM. Skipping...
#
# ==================== CG ====================
# ⚠️ No notices found for CG. Skipping...
#
# ==================== CD ====================
# 🔍 1 notices, 1 pages for CD
# 📄 Fetching page 1/1 for CD
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/CD/CD_combined_data.csv
#
# ==================== CI ====================
# ⚠️ No notices found for CI. Skipping...
#
# ==================== DJ ====================
# ⚠️ No notices found for DJ. Skipping...
#
# ==================== EG ====================
# 🔍 7 notices, 1 pages for EG
# 📄 Fetching page 1/1 for EG
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/EG/EG_combined_data.csv
#
# ==================== GQ ====================
# ⚠️ No notices found for GQ. Skipping...
#
# ==================== ER ====================
# ⚠️ No notices found for ER. Skipping...
#
# ==================== SZ ====================
# 🔍 17 notices, 1 pages for SZ
# 📄 Fetching page 1/1 for SZ
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/SZ/SZ_combined_data.csv
#
# ==================== ET ====================
# 🔍 1 notices, 1 pages for ET
# 📄 Fetching page 1/1 for ET
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/ET/ET_combined_data.csv
#
# ==================== GA ====================
# ⚠️ No notices found for GA. Skipping...
#
# ==================== GM ====================
# ⚠️ No notices found for GM. Skipping...
#
# ==================== GH ====================
# 🔍 2 notices, 1 pages for GH
# 📄 Fetching page 1/1 for GH
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/GH/GH_combined_data.csv
#
# ==================== GN ====================
# 🔍 1 notices, 1 pages for GN
# 📄 Fetching page 1/1 for GN
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/GN/GN_combined_data.csv
#
# ==================== GW ====================
# 🔍 1 notices, 1 pages for GW
# 📄 Fetching page 1/1 for GW
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/GW/GW_combined_data.csv
#
# ==================== KE ====================
# 🔍 3 notices, 1 pages for KE
# 📄 Fetching page 1/1 for KE
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/KE/KE_combined_data.csv
#
# ==================== LS ====================
# ⚠️ No notices found for LS. Skipping...
#
# ==================== LR ====================
# ⚠️ No notices found for LR. Skipping...
#
# ==================== LY ====================
# 🔍 3 notices, 1 pages for LY
# 📄 Fetching page 1/1 for LY
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/LY/LY_combined_data.csv
#
# ==================== MG ====================
# ⚠️ No notices found for MG. Skipping...
#
# ==================== MW ====================
# ⚠️ No notices found for MW. Skipping...
#
# ==================== ML ====================
# 🔍 2 notices, 1 pages for ML
# 📄 Fetching page 1/1 for ML
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/ML/ML_combined_data.csv
#
# ==================== MR ====================
# ⚠️ No notices found for MR. Skipping...
#
# ==================== MU ====================
# ⚠️ No notices found for MU. Skipping...
#
# ==================== MA ====================
# 🔍 12 notices, 1 pages for MA
# 📄 Fetching page 1/1 for MA
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/MA/MA_combined_data.csv
#
# ==================== MZ ====================
# ⚠️ No notices found for MZ. Skipping...
#
# ==================== NE ====================
# 🔍 1 notices, 1 pages for NE
# 📄 Fetching page 1/1 for NE
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/NE/NE_combined_data.csv
#
# ==================== NG ====================
# 🔍 14 notices, 1 pages for NG
# 📄 Fetching page 1/1 for NG
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/NG/NG_combined_data.csv
#
# ==================== RW ====================
# 🔍 10 notices, 1 pages for RW
# 📄 Fetching page 1/1 for RW
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/RW/RW_combined_data.csv
#
# ==================== ST ====================
# ⚠️ No notices found for ST. Skipping...
#
# ==================== SN ====================
# 🔍 1 notices, 1 pages for SN
# 📄 Fetching page 1/1 for SN
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/SN/SN_combined_data.csv
#
# ==================== SC ====================
# ⚠️ No notices found for SC. Skipping...
#
# ==================== SL ====================
# ⚠️ No notices found for SL. Skipping...
#
# ==================== SO ====================
# 🔍 9 notices, 1 pages for SO
# 📄 Fetching page 1/1 for SO
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/SO/SO_combined_data.csv
#
# ==================== ZA ====================
# 🔍 5 notices, 1 pages for ZA
# 📄 Fetching page 1/1 for ZA
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/ZA/ZA_combined_data.csv
#
# ==================== SS ====================
# ⚠️ No notices found for SS. Skipping...
#
# ==================== SD ====================
# 🔍 5 notices, 1 pages for SD
# 📄 Fetching page 1/1 for SD
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/SD/SD_combined_data.csv
#
# ==================== TZ ====================
# 🔍 2 notices, 1 pages for TZ
# 📄 Fetching page 1/1 for TZ
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/TZ/TZ_combined_data.csv
#
# ==================== TG ====================
# ⚠️ No notices found for TG. Skipping...
#
# ==================== TN ====================
# 🔍 5 notices, 1 pages for TN
# 📄 Fetching page 1/1 for TN
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/TN/TN_combined_data.csv
#
# ==================== UG ====================
# ⚠️ No notices found for UG. Skipping...
#
# ==================== ZM ====================
# 🔍 2 notices, 1 pages for ZM
# 📄 Fetching page 1/1 for ZM
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/ZM/ZM_combined_data.csv
#
# ==================== ZW ====================
# 🔍 8 notices, 1 pages for ZW
# 📄 Fetching page 1/1 for ZW
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/ZW/ZW_combined_data.csv
#
# ==================== AG ====================
# ⚠️ No notices found for AG. Skipping...
#
# ==================== AR ====================
# 🔍 208 notices, 11 pages for AR
# 📄 Fetching page 1/11 for AR
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/11 for AR
# 💾 Checkpoint saved (Page 2)
# 📄 Fetching page 3/11 for AR
# 💾 Checkpoint saved (Page 3)
# 📄 Fetching page 4/11 for AR
# 💾 Checkpoint saved (Page 4)
# 📄 Fetching page 5/11 for AR
# 💾 Checkpoint saved (Page 5)
# 📄 Fetching page 6/11 for AR
# 💾 Checkpoint saved (Page 6)
# 📄 Fetching page 7/11 for AR
# 💾 Checkpoint saved (Page 7)
# 📄 Fetching page 8/11 for AR
# 💾 Checkpoint saved (Page 8)
# 📄 Fetching page 9/11 for AR
# 💾 Checkpoint saved (Page 9)
# 📄 Fetching page 10/11 for AR
# 💾 Checkpoint saved (Page 10)
# 📄 Fetching page 11/11 for AR
# 💾 Checkpoint saved (Page 11)
# ✅ Final saved at: /content/AR/AR_combined_data.csv
#
# ==================== AW ====================
# ⚠️ No notices found for AW. Skipping...
#
# ==================== BS ====================
# 🔍 3 notices, 1 pages for BS
# 📄 Fetching page 1/1 for BS
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/BS/BS_combined_data.csv
#
# ==================== BB ====================
# ⚠️ No notices found for BB. Skipping...
#
# ==================== BZ ====================
# 🔍 15 notices, 1 pages for BZ
# 📄 Fetching page 1/1 for BZ
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/BZ/BZ_combined_data.csv
#
# ==================== BO ====================
# 🔍 124 notices, 7 pages for BO
# 📄 Fetching page 1/7 for BO
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/7 for BO
# 💾 Checkpoint saved (Page 2)
# 📄 Fetching page 3/7 for BO
# 💾 Checkpoint saved (Page 3)
# 📄 Fetching page 4/7 for BO
# 💾 Checkpoint saved (Page 4)
# 📄 Fetching page 5/7 for BO
# 💾 Checkpoint saved (Page 5)
# 📄 Fetching page 6/7 for BO
# 💾 Checkpoint saved (Page 6)
# 📄 Fetching page 7/7 for BO
# 💾 Checkpoint saved (Page 7)
# ✅ Final saved at: /content/BO/BO_combined_data.csv
#
# ==================== BR ====================
# 🔍 73 notices, 4 pages for BR
# 📄 Fetching page 1/4 for BR
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/4 for BR
# 💾 Checkpoint saved (Page 2)
# 📄 Fetching page 3/4 for BR
# 💾 Checkpoint saved (Page 3)
# 📄 Fetching page 4/4 for BR
# 💾 Checkpoint saved (Page 4)
# ✅ Final saved at: /content/BR/BR_combined_data.csv
#
# ==================== CA ====================
# 🔍 49 notices, 3 pages for CA
# 📄 Fetching page 1/3 for CA
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/3 for CA
# 💾 Checkpoint saved (Page 2)
# 📄 Fetching page 3/3 for CA
# 💾 Checkpoint saved (Page 3)
# ✅ Final saved at: /content/CA/CA_combined_data.csv
#
# ==================== CL ====================
# 🔍 17 notices, 1 pages for CL
# 📄 Fetching page 1/1 for CL
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/CL/CL_combined_data.csv
#
# ==================== CO ====================
# 🔍 60 notices, 3 pages for CO
# 📄 Fetching page 1/3 for CO
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/3 for CO
# 💾 Checkpoint saved (Page 2)
# 📄 Fetching page 3/3 for CO
# 💾 Checkpoint saved (Page 3)
# ✅ Final saved at: /content/CO/CO_combined_data.csv
#
# ==================== CR ====================
# 🔍 4 notices, 1 pages for CR
# 📄 Fetching page 1/1 for CR
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/CR/CR_combined_data.csv
#
# ==================== CU ====================
# 🔍 5 notices, 1 pages for CU
# 📄 Fetching page 1/1 for CU
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/CU/CU_combined_data.csv
#
# ==================== CW ====================
# ⚠️ No notices found for CW. Skipping...
#
# ==================== DM ====================
# 🔍 3 notices, 1 pages for DM
# 📄 Fetching page 1/1 for DM
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/DM/DM_combined_data.csv
#
# ==================== DO ====================
# 🔍 9 notices, 1 pages for DO
# 📄 Fetching page 1/1 for DO
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/DO/DO_combined_data.csv
#
# ==================== EC ====================
# 🔍 14 notices, 1 pages for EC
# 📄 Fetching page 1/1 for EC
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/EC/EC_combined_data.csv
#
# ==================== SV ====================
# 🔍 830 notices, 42 pages for SV
# 📄 Fetching page 1/42 for SV
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/42 for SV
# 💾 Checkpoint saved (Page 2)
# 📄 Fetching page 3/42 for SV
# 💾 Checkpoint saved (Page 3)
# 📄 Fetching page 4/42 for SV
# 💾 Checkpoint saved (Page 4)
# 📄 Fetching page 5/42 for SV
# 💾 Checkpoint saved (Page 5)
# 📄 Fetching page 6/42 for SV
# 💾 Checkpoint saved (Page 6)
# 📄 Fetching page 7/42 for SV
# 💾 Checkpoint saved (Page 7)
# 📄 Fetching page 8/42 for SV
# 💾 Checkpoint saved (Page 8)
# 📄 Fetching page 9/42 for SV
# 💾 Checkpoint saved (Page 9)
# 📄 Fetching page 10/42 for SV
# 💾 Checkpoint saved (Page 10)
# 📄 Fetching page 11/42 for SV
# 💾 Checkpoint saved (Page 11)
# 📄 Fetching page 12/42 for SV
# 💾 Checkpoint saved (Page 12)
# 📄 Fetching page 13/42 for SV
# 💾 Checkpoint saved (Page 13)
# 📄 Fetching page 14/42 for SV
# 💾 Checkpoint saved (Page 14)
# 📄 Fetching page 15/42 for SV
# 💾 Checkpoint saved (Page 15)
# 📄 Fetching page 16/42 for SV
# 💾 Checkpoint saved (Page 16)
# 📄 Fetching page 17/42 for SV
# 💾 Checkpoint saved (Page 17)
# 📄 Fetching page 18/42 for SV
# 💾 Checkpoint saved (Page 18)
# 📄 Fetching page 19/42 for SV
# 💾 Checkpoint saved (Page 19)
# 📄 Fetching page 20/42 for SV
# 💾 Checkpoint saved (Page 20)
# 📄 Fetching page 21/42 for SV
# 💾 Checkpoint saved (Page 21)
# 📄 Fetching page 22/42 for SV
# 💾 Checkpoint saved (Page 22)
# 📄 Fetching page 23/42 for SV
# 💾 Checkpoint saved (Page 23)
# 📄 Fetching page 24/42 for SV
# 💾 Checkpoint saved (Page 24)
# 📄 Fetching page 25/42 for SV
# 💾 Checkpoint saved (Page 25)
# 📄 Fetching page 26/42 for SV
# 💾 Checkpoint saved (Page 26)
# 📄 Fetching page 27/42 for SV
# 💾 Checkpoint saved (Page 27)
# 📄 Fetching page 28/42 for SV
# 💾 Checkpoint saved (Page 28)
# 📄 Fetching page 29/42 for SV
# 💾 Checkpoint saved (Page 29)
# 📄 Fetching page 30/42 for SV
# 💾 Checkpoint saved (Page 30)
# 📄 Fetching page 31/42 for SV
# 💾 Checkpoint saved (Page 31)
# 📄 Fetching page 32/42 for SV
# 💾 Checkpoint saved (Page 32)
# 📄 Fetching page 33/42 for SV
# 💾 Checkpoint saved (Page 33)
# 📄 Fetching page 34/42 for SV
# 💾 Checkpoint saved (Page 34)
# 📄 Fetching page 35/42 for SV
# 💾 Checkpoint saved (Page 35)
# 📄 Fetching page 36/42 for SV
# 💾 Checkpoint saved (Page 36)
# 📄 Fetching page 37/42 for SV
# 💾 Checkpoint saved (Page 37)
# 📄 Fetching page 38/42 for SV
# 💾 Checkpoint saved (Page 38)
# 📄 Fetching page 39/42 for SV
# 💾 Checkpoint saved (Page 39)
# 📄 Fetching page 40/42 for SV
# 💾 Checkpoint saved (Page 40)
# 📄 Fetching page 41/42 for SV
# 💾 Checkpoint saved (Page 41)
# 📄 Fetching page 42/42 for SV
# 💾 Checkpoint saved (Page 42)
# ✅ Final saved at: /content/SV/SV_combined_data.csv
#
# ==================== GD ====================
# ⚠️ No notices found for GD. Skipping...
#
# ==================== GT ====================
# 🔍 146 notices, 8 pages for GT
# 📄 Fetching page 1/8 for GT
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/8 for GT
# 💾 Checkpoint saved (Page 2)
# 📄 Fetching page 3/8 for GT
# 💾 Checkpoint saved (Page 3)
# 📄 Fetching page 4/8 for GT
# 💾 Checkpoint saved (Page 4)
# 📄 Fetching page 5/8 for GT
# 💾 Checkpoint saved (Page 5)
# 📄 Fetching page 6/8 for GT
# 💾 Checkpoint saved (Page 6)
# 📄 Fetching page 7/8 for GT
# 💾 Checkpoint saved (Page 7)
# 📄 Fetching page 8/8 for GT
# 💾 Checkpoint saved (Page 8)
# ✅ Final saved at: /content/GT/GT_combined_data.csv
#
# ==================== GY ====================
# 🔍 5 notices, 1 pages for GY
# 📄 Fetching page 1/1 for GY
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/GY/GY_combined_data.csv
#
# ==================== HT ====================
# 🔍 2 notices, 1 pages for HT
# 📄 Fetching page 1/1 for HT
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/HT/HT_combined_data.csv
#
# ==================== HN ====================
# 🔍 27 notices, 2 pages for HN
# 📄 Fetching page 1/2 for HN
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/2 for HN
# 💾 Checkpoint saved (Page 2)
# ✅ Final saved at: /content/HN/HN_combined_data.csv
#
# ==================== JM ====================
# 🔍 52 notices, 3 pages for JM
# 📄 Fetching page 1/3 for JM
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/3 for JM
# 💾 Checkpoint saved (Page 2)
# 📄 Fetching page 3/3 for JM
# 💾 Checkpoint saved (Page 3)
# ✅ Final saved at: /content/JM/JM_combined_data.csv
#
# ==================== MX ====================
# 🔍 41 notices, 3 pages for MX
# 📄 Fetching page 1/3 for MX
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/3 for MX
# 💾 Checkpoint saved (Page 2)
# 📄 Fetching page 3/3 for MX
# 💾 Checkpoint saved (Page 3)
# ✅ Final saved at: /content/MX/MX_combined_data.csv
#
# ==================== NI ====================
# 🔍 61 notices, 4 pages for NI
# 📄 Fetching page 1/4 for NI
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/4 for NI
# 💾 Checkpoint saved (Page 2)
# 📄 Fetching page 3/4 for NI
# 💾 Checkpoint saved (Page 3)
# 📄 Fetching page 4/4 for NI
# 💾 Checkpoint saved (Page 4)
# ✅ Final saved at: /content/NI/NI_combined_data.csv
#
# ==================== PA ====================
# 🔍 3 notices, 1 pages for PA
# 📄 Fetching page 1/1 for PA
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/PA/PA_combined_data.csv
#
# ==================== PY ====================
# 🔍 68 notices, 4 pages for PY
# 📄 Fetching page 1/4 for PY
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/4 for PY
# 💾 Checkpoint saved (Page 2)
# 📄 Fetching page 3/4 for PY
# 💾 Checkpoint saved (Page 3)
# 📄 Fetching page 4/4 for PY
# 💾 Checkpoint saved (Page 4)
# ✅ Final saved at: /content/PY/PY_combined_data.csv
#
# ==================== PE ====================
# 🔍 20 notices, 1 pages for PE
# 📄 Fetching page 1/1 for PE
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/PE/PE_combined_data.csv
#
# ==================== SX ====================
# ⚠️ No notices found for SX. Skipping...
#
# ==================== KN ====================
# ⚠️ No notices found for KN. Skipping...
#
# ==================== LC ====================
# 🔍 1 notices, 1 pages for LC
# 📄 Fetching page 1/1 for LC
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/LC/LC_combined_data.csv
#
# ==================== VC ====================
# ⚠️ No notices found for VC. Skipping...
#
# ==================== SR ====================
# 🔍 10 notices, 1 pages for SR
# 📄 Fetching page 1/1 for SR
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/SR/SR_combined_data.csv
#
# ==================== TT ====================
# ⚠️ No notices found for TT. Skipping...
#
# ==================== US ====================
# 🔍 100 notices, 5 pages for US
# 📄 Fetching page 1/5 for US
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/5 for US
# 💾 Checkpoint saved (Page 2)
# 📄 Fetching page 3/5 for US
# 💾 Checkpoint saved (Page 3)
# 📄 Fetching page 4/5 for US
# 💾 Checkpoint saved (Page 4)
# 📄 Fetching page 5/5 for US
# 💾 Checkpoint saved (Page 5)
# ✅ Final saved at: /content/US/US_combined_data.csv
#
# ==================== UY ====================
# 🔍 44 notices, 3 pages for UY
# 📄 Fetching page 1/3 for UY
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/3 for UY
# 💾 Checkpoint saved (Page 2)
# 📄 Fetching page 3/3 for UY
# 💾 Checkpoint saved (Page 3)
# ✅ Final saved at: /content/UY/UY_combined_data.csv
#
# ==================== VE ====================
# 🔍 26 notices, 2 pages for VE
# 📄 Fetching page 1/2 for VE
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/2 for VE
# 💾 Checkpoint saved (Page 2)
# ✅ Final saved at: /content/VE/VE_combined_data.csv
#
# ==================== AU ====================
# 🔍 6 notices, 1 pages for AU
# 📄 Fetching page 1/1 for AU
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/AU/AU_combined_data.csv
#
# ==================== BH ====================
# ⚠️ No notices found for BH. Skipping...
#
# ==================== BD ====================
# 🔍 60 notices, 3 pages for BD
# 📄 Fetching page 1/3 for BD
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/3 for BD
# 💾 Checkpoint saved (Page 2)
# 📄 Fetching page 3/3 for BD
# 💾 Checkpoint saved (Page 3)
# ✅ Final saved at: /content/BD/BD_combined_data.csv
#
# ==================== BT ====================
# 🔍 1 notices, 1 pages for BT
# 📄 Fetching page 1/1 for BT
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/BT/BT_combined_data.csv
#
# ==================== BN ====================
# ⚠️ No notices found for BN. Skipping...
#
# ==================== KH ====================
# 🔍 1 notices, 1 pages for KH
# 📄 Fetching page 1/1 for KH
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/KH/KH_combined_data.csv
#
# ==================== CN ====================
# 🔍 62 notices, 4 pages for CN
# 📄 Fetching page 1/4 for CN
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/4 for CN
# 💾 Checkpoint saved (Page 2)
# 📄 Fetching page 3/4 for CN
# 💾 Checkpoint saved (Page 3)
# 📄 Fetching page 4/4 for CN
# 💾 Checkpoint saved (Page 4)
# ✅ Final saved at: /content/CN/CN_combined_data.csv
#
# ==================== FJ ====================
# ⚠️ No notices found for FJ. Skipping...
#
# ==================== IN ====================
# 🔍 207 notices, 11 pages for IN
# 📄 Fetching page 1/11 for IN
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/11 for IN
# 💾 Checkpoint saved (Page 2)
# 📄 Fetching page 3/11 for IN
# 💾 Checkpoint saved (Page 3)
# 📄 Fetching page 4/11 for IN
# 💾 Checkpoint saved (Page 4)
# 📄 Fetching page 5/11 for IN
# 💾 Checkpoint saved (Page 5)
# 📄 Fetching page 6/11 for IN
# 💾 Checkpoint saved (Page 6)
# 📄 Fetching page 7/11 for IN
# 💾 Checkpoint saved (Page 7)
# 📄 Fetching page 8/11 for IN
# 💾 Checkpoint saved (Page 8)
# 📄 Fetching page 9/11 for IN
# 💾 Checkpoint saved (Page 9)
# 📄 Fetching page 10/11 for IN
# 💾 Checkpoint saved (Page 10)
# 📄 Fetching page 11/11 for IN
# 💾 Checkpoint saved (Page 11)
# ✅ Final saved at: /content/IN/IN_combined_data.csv
#
# ==================== ID ====================
# 🔍 8 notices, 1 pages for ID
# 📄 Fetching page 1/1 for ID
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/ID/ID_combined_data.csv
#
# ==================== IR ====================
# 🔍 20 notices, 1 pages for IR
# 📄 Fetching page 1/1 for IR
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/IR/IR_combined_data.csv
#
# ==================== IQ ====================
# 🔍 9 notices, 1 pages for IQ
# 📄 Fetching page 1/1 for IQ
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/IQ/IQ_combined_data.csv
#
# ==================== JP ====================
# 🔍 3 notices, 1 pages for JP
# 📄 Fetching page 1/1 for JP
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/JP/JP_combined_data.csv
#
# ==================== JO ====================
# 🔍 3 notices, 1 pages for JO
# 📄 Fetching page 1/1 for JO
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/JO/JO_combined_data.csv
#
# ==================== KZ ====================
# 🔍 11 notices, 1 pages for KZ
# 📄 Fetching page 1/1 for KZ
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/KZ/KZ_combined_data.csv
#
# ==================== KI ====================
# ⚠️ No notices found for KI. Skipping...
#
# ==================== KR ====================
# 🔍 1 notices, 1 pages for KR
# 📄 Fetching page 1/1 for KR
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/KR/KR_combined_data.csv
#
# ==================== KW ====================
# 🔍 1 notices, 1 pages for KW
# 📄 Fetching page 1/1 for KW
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/KW/KW_combined_data.csv
#
# ==================== KG ====================
# 🔍 36 notices, 2 pages for KG
# 📄 Fetching page 1/2 for KG
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/2 for KG
# 💾 Checkpoint saved (Page 2)
# ✅ Final saved at: /content/KG/KG_combined_data.csv
#
# ==================== LA ====================
# 🔍 1 notices, 1 pages for LA
# 📄 Fetching page 1/1 for LA
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/LA/LA_combined_data.csv
#
# ==================== LB ====================
# 🔍 11 notices, 1 pages for LB
# 📄 Fetching page 1/1 for LB
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/LB/LB_combined_data.csv
#
# ==================== MY ====================
# 🔍 4 notices, 1 pages for MY
# 📄 Fetching page 1/1 for MY
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/MY/MY_combined_data.csv
#
# ==================== MV ====================
# 🔍 9 notices, 1 pages for MV
# 📄 Fetching page 1/1 for MV
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/MV/MV_combined_data.csv
#
# ==================== MH ====================
# ⚠️ No notices found for MH. Skipping...
#
# ==================== MN ====================
# 🔍 3 notices, 1 pages for MN
# 📄 Fetching page 1/1 for MN
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/MN/MN_combined_data.csv
#
# ==================== MM ====================
# 🔍 2 notices, 1 pages for MM
# 📄 Fetching page 1/1 for MM
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/MM/MM_combined_data.csv
#
# ==================== NR ====================
# ⚠️ No notices found for NR. Skipping...
#
# ==================== NP ====================
# 🔍 15 notices, 1 pages for NP
# 📄 Fetching page 1/1 for NP
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/NP/NP_combined_data.csv
#
# ==================== NZ ====================
# ⚠️ No notices found for NZ. Skipping...
#
# ==================== OM ====================
# ⚠️ No notices found for OM. Skipping...
#
# ==================== PK ====================
# 🔍 177 notices, 9 pages for PK
# 📄 Fetching page 1/9 for PK
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/9 for PK
# 💾 Checkpoint saved (Page 2)
# 📄 Fetching page 3/9 for PK
# 💾 Checkpoint saved (Page 3)
# 📄 Fetching page 4/9 for PK
# 💾 Checkpoint saved (Page 4)
# 📄 Fetching page 5/9 for PK
# 💾 Checkpoint saved (Page 5)
# 📄 Fetching page 6/9 for PK
# 💾 Checkpoint saved (Page 6)
# 📄 Fetching page 7/9 for PK
# 💾 Checkpoint saved (Page 7)
# 📄 Fetching page 8/9 for PK
# 💾 Checkpoint saved (Page 8)
# 📄 Fetching page 9/9 for PK
# 💾 Checkpoint saved (Page 9)
# ✅ Final saved at: /content/PK/PK_combined_data.csv
#
# ==================== PW ====================
# ⚠️ No notices found for PW. Skipping...
#
# ==================== PS ====================
# 🔍 2 notices, 1 pages for PS
# 📄 Fetching page 1/1 for PS
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/PS/PS_combined_data.csv
#
# ==================== PG ====================
# ⚠️ No notices found for PG. Skipping...
#
# ==================== PH ====================
# 🔍 11 notices, 1 pages for PH
# 📄 Fetching page 1/1 for PH
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/PH/PH_combined_data.csv
#
# ==================== QA ====================
# ⚠️ No notices found for QA. Skipping...
#
# ==================== WS ====================
# ⚠️ No notices found for WS. Skipping...
#
# ==================== SA ====================
# 🔍 2 notices, 1 pages for SA
# 📄 Fetching page 1/1 for SA
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/SA/SA_combined_data.csv
#
# ==================== SG ====================
# 🔍 5 notices, 1 pages for SG
# 📄 Fetching page 1/1 for SG
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/SG/SG_combined_data.csv
#
# ==================== SB ====================
# ⚠️ No notices found for SB. Skipping...
#
# ==================== LK ====================
# 🔍 6 notices, 1 pages for LK
# 📄 Fetching page 1/1 for LK
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/LK/LK_combined_data.csv
#
# ==================== SY ====================
# 🔍 10 notices, 1 pages for SY
# 📄 Fetching page 1/1 for SY
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/SY/SY_combined_data.csv
#
# ==================== TJ ====================
# 🔍 37 notices, 2 pages for TJ
# 📄 Fetching page 1/2 for TJ
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/2 for TJ
# 💾 Checkpoint saved (Page 2)
# ✅ Final saved at: /content/TJ/TJ_combined_data.csv
#
# ==================== TH ====================
# 🔍 12 notices, 1 pages for TH
# 📄 Fetching page 1/1 for TH
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/TH/TH_combined_data.csv
#
# ==================== TL ====================
# ⚠️ No notices found for TL. Skipping...
#
# ==================== TO ====================
# ⚠️ No notices found for TO. Skipping...
#
# ==================== TM ====================
# 🔍 1 notices, 1 pages for TM
# 📄 Fetching page 1/1 for TM
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/TM/TM_combined_data.csv
#
# ==================== AE ====================
# ⚠️ No notices found for AE. Skipping...
#
# ==================== UZ ====================
# 🔍 22 notices, 2 pages for UZ
# 📄 Fetching page 1/2 for UZ
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/2 for UZ
# 💾 Checkpoint saved (Page 2)
# ✅ Final saved at: /content/UZ/UZ_combined_data.csv
#
# ==================== VU ====================
# ⚠️ No notices found for VU. Skipping...
#
# ==================== VN ====================
# 🔍 47 notices, 3 pages for VN
# 📄 Fetching page 1/3 for VN
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/3 for VN
# 💾 Checkpoint saved (Page 2)
# 📄 Fetching page 3/3 for VN
# 💾 Checkpoint saved (Page 3)
# ✅ Final saved at: /content/VN/VN_combined_data.csv
#
# ==================== YE ====================
# 🔍 1 notices, 1 pages for YE
# 📄 Fetching page 1/1 for YE
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/YE/YE_combined_data.csv
#
# ==================== AL ====================
# 🔍 10 notices, 1 pages for AL
# 📄 Fetching page 1/1 for AL
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/AL/AL_combined_data.csv
#
# ==================== AD ====================
# ⚠️ No notices found for AD. Skipping...
#
# ==================== AM ====================
# 🔍 13 notices, 1 pages for AM
# 📄 Fetching page 1/1 for AM
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/AM/AM_combined_data.csv
#
# ==================== AT ====================
# 🔍 5 notices, 1 pages for AT
# 📄 Fetching page 1/1 for AT
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/AT/AT_combined_data.csv
#
# ==================== AZ ====================
# 🔍 37 notices, 2 pages for AZ
# 📄 Fetching page 1/2 for AZ
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/2 for AZ
# 💾 Checkpoint saved (Page 2)
# ✅ Final saved at: /content/AZ/AZ_combined_data.csv
#
# ==================== BY ====================
# 🔍 3 notices, 1 pages for BY
# 📄 Fetching page 1/1 for BY
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/BY/BY_combined_data.csv
#
# ==================== BE ====================
# 🔍 8 notices, 1 pages for BE
# 📄 Fetching page 1/1 for BE
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/BE/BE_combined_data.csv
#
# ==================== BA ====================
# 🔍 70 notices, 4 pages for BA
# 📄 Fetching page 1/4 for BA
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/4 for BA
# 💾 Checkpoint saved (Page 2)
# 📄 Fetching page 3/4 for BA
# 💾 Checkpoint saved (Page 3)
# 📄 Fetching page 4/4 for BA
# 💾 Checkpoint saved (Page 4)
# ✅ Final saved at: /content/BA/BA_combined_data.csv
#
# ==================== BG ====================
# 🔍 36 notices, 2 pages for BG
# 📄 Fetching page 1/2 for BG
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/2 for BG
# 💾 Checkpoint saved (Page 2)
# ✅ Final saved at: /content/BG/BG_combined_data.csv
#
# ==================== HR ====================
# 🔍 14 notices, 1 pages for HR
# 📄 Fetching page 1/1 for HR
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/HR/HR_combined_data.csv
#
# ==================== CY ====================
# 🔍 2 notices, 1 pages for CY
# 📄 Fetching page 1/1 for CY
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/CY/CY_combined_data.csv
#
# ==================== CZ ====================
# 🔍 15 notices, 1 pages for CZ
# 📄 Fetching page 1/1 for CZ
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/CZ/CZ_combined_data.csv
#
# ==================== DK ====================
# 🔍 5 notices, 1 pages for DK
# 📄 Fetching page 1/1 for DK
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/DK/DK_combined_data.csv
#
# ==================== EE ====================
# 🔍 3 notices, 1 pages for EE
# 📄 Fetching page 1/1 for EE
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/EE/EE_combined_data.csv
#
# ==================== FI ====================
# 🔍 1 notices, 1 pages for FI
# 📄 Fetching page 1/1 for FI
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/FI/FI_combined_data.csv
#
# ==================== FR ====================
# 🔍 52 notices, 3 pages for FR
# 📄 Fetching page 1/3 for FR
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/3 for FR
# 💾 Checkpoint saved (Page 2)
# 📄 Fetching page 3/3 for FR
# 💾 Checkpoint saved (Page 3)
# ✅ Final saved at: /content/FR/FR_combined_data.csv
#
# ==================== GE ====================
# 🔍 39 notices, 2 pages for GE
# 📄 Fetching page 1/2 for GE
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/2 for GE
# 💾 Checkpoint saved (Page 2)
# ✅ Final saved at: /content/GE/GE_combined_data.csv
#
# ==================== DE ====================
# 🔍 16 notices, 1 pages for DE
# 📄 Fetching page 1/1 for DE
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/DE/DE_combined_data.csv
#
# ==================== GR ====================
# 🔍 11 notices, 1 pages for GR
# 📄 Fetching page 1/1 for GR
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/GR/GR_combined_data.csv
#
# ==================== HU ====================
# 🔍 7 notices, 1 pages for HU
# 📄 Fetching page 1/1 for HU
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/HU/HU_combined_data.csv
#
# ==================== IS ====================
# 🔍 1 notices, 1 pages for IS
# 📄 Fetching page 1/1 for IS
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/IS/IS_combined_data.csv
#
# ==================== IE ====================
# 🔍 1 notices, 1 pages for IE
# 📄 Fetching page 1/1 for IE
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/IE/IE_combined_data.csv
#
# ==================== IL ====================
# 🔍 26 notices, 2 pages for IL
# 📄 Fetching page 1/2 for IL
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/2 for IL
# 💾 Checkpoint saved (Page 2)
# ✅ Final saved at: /content/IL/IL_combined_data.csv
#
# ==================== IT ====================
# 🔍 6 notices, 1 pages for IT
# 📄 Fetching page 1/1 for IT
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/IT/IT_combined_data.csv
#
# ==================== LV ====================
# 🔍 4 notices, 1 pages for LV
# 📄 Fetching page 1/1 for LV
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/LV/LV_combined_data.csv
#
# ==================== LI ====================
# ⚠️ No notices found for LI. Skipping...
#
# ==================== LT ====================
# 🔍 6 notices, 1 pages for LT
# 📄 Fetching page 1/1 for LT
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/LT/LT_combined_data.csv
#
# ==================== LU ====================
# ⚠️ No notices found for LU. Skipping...
#
# ==================== MT ====================
# ⚠️ No notices found for MT. Skipping...
#
# ==================== MD ====================
# 🔍 22 notices, 2 pages for MD
# 📄 Fetching page 1/2 for MD
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/2 for MD
# 💾 Checkpoint saved (Page 2)
# ✅ Final saved at: /content/MD/MD_combined_data.csv
#
# ==================== MC ====================
# ⚠️ No notices found for MC. Skipping...
#
# ==================== ME ====================
# 🔍 11 notices, 1 pages for ME
# 📄 Fetching page 1/1 for ME
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/ME/ME_combined_data.csv
#
# ==================== NL ====================
# 🔍 12 notices, 1 pages for NL
# 📄 Fetching page 1/1 for NL
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/NL/NL_combined_data.csv
#
# ==================== MK ====================
# 🔍 2 notices, 1 pages for MK
# 📄 Fetching page 1/1 for MK
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/MK/MK_combined_data.csv
#
# ==================== NO ====================
# 🔍 3 notices, 1 pages for NO
# 📄 Fetching page 1/1 for NO
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/NO/NO_combined_data.csv
#
# ==================== PL ====================
# 🔍 40 notices, 2 pages for PL
# 📄 Fetching page 1/2 for PL
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/2 for PL
# 💾 Checkpoint saved (Page 2)
# ✅ Final saved at: /content/PL/PL_combined_data.csv
#
# ==================== PT ====================
# 🔍 10 notices, 1 pages for PT
# 📄 Fetching page 1/1 for PT
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/PT/PT_combined_data.csv
#
# ==================== RO ====================
# 🔍 29 notices, 2 pages for RO
# 📄 Fetching page 1/2 for RO
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/2 for RO
# 💾 Checkpoint saved (Page 2)
# ✅ Final saved at: /content/RO/RO_combined_data.csv
#
# ==================== RU ====================
# 🔍 3037 notices, 152 pages for RU
# 📄 Fetching page 1/152 for RU
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/152 for RU
# 💾 Checkpoint saved (Page 2)
# 📄 Fetching page 3/152 for RU
# 💾 Checkpoint saved (Page 3)
# 📄 Fetching page 4/152 for RU
# 💾 Checkpoint saved (Page 4)
# 📄 Fetching page 5/152 for RU
# 💾 Checkpoint saved (Page 5)
# 📄 Fetching page 6/152 for RU
# 💾 Checkpoint saved (Page 6)
# 📄 Fetching page 7/152 for RU
# 💾 Checkpoint saved (Page 7)
# 📄 Fetching page 8/152 for RU
# 💾 Checkpoint saved (Page 8)
# 📄 Fetching page 9/152 for RU
# 💾 Checkpoint saved (Page 9)
# 📄 Fetching page 10/152 for RU
# 💾 Checkpoint saved (Page 10)
# 📄 Fetching page 11/152 for RU
# 💾 Checkpoint saved (Page 11)
# 📄 Fetching page 12/152 for RU
# 💾 Checkpoint saved (Page 12)
# 📄 Fetching page 13/152 for RU
# 💾 Checkpoint saved (Page 13)
# 📄 Fetching page 14/152 for RU
# 💾 Checkpoint saved (Page 14)
# 📄 Fetching page 15/152 for RU
# 💾 Checkpoint saved (Page 15)
# 📄 Fetching page 16/152 for RU
# 💾 Checkpoint saved (Page 16)
# 📄 Fetching page 17/152 for RU
# 💾 Checkpoint saved (Page 17)
# 📄 Fetching page 18/152 for RU
# 💾 Checkpoint saved (Page 18)
# 📄 Fetching page 19/152 for RU
# 💾 Checkpoint saved (Page 19)
# 📄 Fetching page 20/152 for RU
# 💾 Checkpoint saved (Page 20)
# 📄 Fetching page 21/152 for RU
# 💾 Checkpoint saved (Page 21)
# 📄 Fetching page 22/152 for RU
# 💾 Checkpoint saved (Page 22)
# 📄 Fetching page 23/152 for RU
# 💾 Checkpoint saved (Page 23)
# 📄 Fetching page 24/152 for RU
# 💾 Checkpoint saved (Page 24)
# 📄 Fetching page 25/152 for RU
# 💾 Checkpoint saved (Page 25)
# 📄 Fetching page 26/152 for RU
# 💾 Checkpoint saved (Page 26)
# 📄 Fetching page 27/152 for RU
# 💾 Checkpoint saved (Page 27)
# 📄 Fetching page 28/152 for RU
# 💾 Checkpoint saved (Page 28)
# 📄 Fetching page 29/152 for RU
# 💾 Checkpoint saved (Page 29)
# 📄 Fetching page 30/152 for RU
# 💾 Checkpoint saved (Page 30)
# 📄 Fetching page 31/152 for RU
# 💾 Checkpoint saved (Page 31)
# 📄 Fetching page 32/152 for RU
# 💾 Checkpoint saved (Page 32)
# 📄 Fetching page 33/152 for RU
# 💾 Checkpoint saved (Page 33)
# 📄 Fetching page 34/152 for RU
# 💾 Checkpoint saved (Page 34)
# 📄 Fetching page 35/152 for RU
# 💾 Checkpoint saved (Page 35)
# 📄 Fetching page 36/152 for RU
# 💾 Checkpoint saved (Page 36)
# 📄 Fetching page 37/152 for RU
# 💾 Checkpoint saved (Page 37)
# 📄 Fetching page 38/152 for RU
# 💾 Checkpoint saved (Page 38)
# 📄 Fetching page 39/152 for RU
# 💾 Checkpoint saved (Page 39)
# 📄 Fetching page 40/152 for RU
# 💾 Checkpoint saved (Page 40)
# 📄 Fetching page 41/152 for RU
# 💾 Checkpoint saved (Page 41)
# 📄 Fetching page 42/152 for RU
# 💾 Checkpoint saved (Page 42)
# 📄 Fetching page 43/152 for RU
# 💾 Checkpoint saved (Page 43)
# 📄 Fetching page 44/152 for RU
# 💾 Checkpoint saved (Page 44)
# 📄 Fetching page 45/152 for RU
# 💾 Checkpoint saved (Page 45)
# 📄 Fetching page 46/152 for RU
# 💾 Checkpoint saved (Page 46)
# 📄 Fetching page 47/152 for RU
# 💾 Checkpoint saved (Page 47)
# 📄 Fetching page 48/152 for RU
# 💾 Checkpoint saved (Page 48)
# 📄 Fetching page 49/152 for RU
# 💾 Checkpoint saved (Page 49)
# 📄 Fetching page 50/152 for RU
# 💾 Checkpoint saved (Page 50)
# 📄 Fetching page 51/152 for RU
# 💾 Checkpoint saved (Page 51)
# 📄 Fetching page 52/152 for RU
# 💾 Checkpoint saved (Page 52)
# 📄 Fetching page 53/152 for RU
# 💾 Checkpoint saved (Page 53)
# 📄 Fetching page 54/152 for RU
# 💾 Checkpoint saved (Page 54)
# 📄 Fetching page 55/152 for RU
# 💾 Checkpoint saved (Page 55)
# 📄 Fetching page 56/152 for RU
# 💾 Checkpoint saved (Page 56)
# 📄 Fetching page 57/152 for RU
# 💾 Checkpoint saved (Page 57)
# 📄 Fetching page 58/152 for RU
# 💾 Checkpoint saved (Page 58)
# 📄 Fetching page 59/152 for RU
# 💾 Checkpoint saved (Page 59)
# 📄 Fetching page 60/152 for RU
# 💾 Checkpoint saved (Page 60)
# 📄 Fetching page 61/152 for RU
# 💾 Checkpoint saved (Page 61)
# 📄 Fetching page 62/152 for RU
# 💾 Checkpoint saved (Page 62)
# 📄 Fetching page 63/152 for RU
# 💾 Checkpoint saved (Page 63)
# 📄 Fetching page 64/152 for RU
# 💾 Checkpoint saved (Page 64)
# 📄 Fetching page 65/152 for RU
# 💾 Checkpoint saved (Page 65)
# 📄 Fetching page 66/152 for RU
# 💾 Checkpoint saved (Page 66)
# 📄 Fetching page 67/152 for RU
# 💾 Checkpoint saved (Page 67)
# 📄 Fetching page 68/152 for RU
# 💾 Checkpoint saved (Page 68)
# 📄 Fetching page 69/152 for RU
# 💾 Checkpoint saved (Page 69)
# 📄 Fetching page 70/152 for RU
# 💾 Checkpoint saved (Page 70)
# 📄 Fetching page 71/152 for RU
# 💾 Checkpoint saved (Page 71)
# 📄 Fetching page 72/152 for RU
# 💾 Checkpoint saved (Page 72)
# 📄 Fetching page 73/152 for RU
# 💾 Checkpoint saved (Page 73)
# 📄 Fetching page 74/152 for RU
# 💾 Checkpoint saved (Page 74)
# 📄 Fetching page 75/152 for RU
# 💾 Checkpoint saved (Page 75)
# 📄 Fetching page 76/152 for RU
# 💾 Checkpoint saved (Page 76)
# 📄 Fetching page 77/152 for RU
# 💾 Checkpoint saved (Page 77)
# 📄 Fetching page 78/152 for RU
# 💾 Checkpoint saved (Page 78)
# 📄 Fetching page 79/152 for RU
# 💾 Checkpoint saved (Page 79)
# 📄 Fetching page 80/152 for RU
# 💾 Checkpoint saved (Page 80)
# 📄 Fetching page 81/152 for RU
# 💾 Checkpoint saved (Page 81)
# 📄 Fetching page 82/152 for RU
# 💾 Checkpoint saved (Page 82)
# 📄 Fetching page 83/152 for RU
# 💾 Checkpoint saved (Page 83)
# 📄 Fetching page 84/152 for RU
# 💾 Checkpoint saved (Page 84)
# 📄 Fetching page 85/152 for RU
# 💾 Checkpoint saved (Page 85)
# 📄 Fetching page 86/152 for RU
# 💾 Checkpoint saved (Page 86)
# 📄 Fetching page 87/152 for RU
# 💾 Checkpoint saved (Page 87)
# 📄 Fetching page 88/152 for RU
# 💾 Checkpoint saved (Page 88)
# 📄 Fetching page 89/152 for RU
# 💾 Checkpoint saved (Page 89)
# 📄 Fetching page 90/152 for RU
# 💾 Checkpoint saved (Page 90)
# 📄 Fetching page 91/152 for RU
# 💾 Checkpoint saved (Page 91)
# 📄 Fetching page 92/152 for RU
# 💾 Checkpoint saved (Page 92)
# 📄 Fetching page 93/152 for RU
# 💾 Checkpoint saved (Page 93)
# 📄 Fetching page 94/152 for RU
# 💾 Checkpoint saved (Page 94)
# 📄 Fetching page 95/152 for RU
# 💾 Checkpoint saved (Page 95)
# 📄 Fetching page 96/152 for RU
# 💾 Checkpoint saved (Page 96)
# 📄 Fetching page 97/152 for RU
# 💾 Checkpoint saved (Page 97)
# 📄 Fetching page 98/152 for RU
# 💾 Checkpoint saved (Page 98)
# 📄 Fetching page 99/152 for RU
# 💾 Checkpoint saved (Page 99)
# 📄 Fetching page 100/152 for RU
# 💾 Checkpoint saved (Page 100)
# 📄 Fetching page 101/152 for RU
# 💾 Checkpoint saved (Page 101)
# 📄 Fetching page 102/152 for RU
# 💾 Checkpoint saved (Page 102)
# 📄 Fetching page 103/152 for RU
# 💾 Checkpoint saved (Page 103)
# 📄 Fetching page 104/152 for RU
# 💾 Checkpoint saved (Page 104)
# 📄 Fetching page 105/152 for RU
# 💾 Checkpoint saved (Page 105)
# 📄 Fetching page 106/152 for RU
# 💾 Checkpoint saved (Page 106)
# 📄 Fetching page 107/152 for RU
# 💾 Checkpoint saved (Page 107)
# 📄 Fetching page 108/152 for RU
# 💾 Checkpoint saved (Page 108)
# 📄 Fetching page 109/152 for RU
# 💾 Checkpoint saved (Page 109)
# 📄 Fetching page 110/152 for RU
# 💾 Checkpoint saved (Page 110)
# 📄 Fetching page 111/152 for RU
# 💾 Checkpoint saved (Page 111)
# 📄 Fetching page 112/152 for RU
# 💾 Checkpoint saved (Page 112)
# 📄 Fetching page 113/152 for RU
# 💾 Checkpoint saved (Page 113)
# 📄 Fetching page 114/152 for RU
# 💾 Checkpoint saved (Page 114)
# 📄 Fetching page 115/152 for RU
# 💾 Checkpoint saved (Page 115)
# 📄 Fetching page 116/152 for RU
# 💾 Checkpoint saved (Page 116)
# 📄 Fetching page 117/152 for RU
# 💾 Checkpoint saved (Page 117)
# 📄 Fetching page 118/152 for RU
# 💾 Checkpoint saved (Page 118)
# 📄 Fetching page 119/152 for RU
# 💾 Checkpoint saved (Page 119)
# 📄 Fetching page 120/152 for RU
# 💾 Checkpoint saved (Page 120)
# 📄 Fetching page 121/152 for RU
# 💾 Checkpoint saved (Page 121)
# 📄 Fetching page 122/152 for RU
# 💾 Checkpoint saved (Page 122)
# 📄 Fetching page 123/152 for RU
# 💾 Checkpoint saved (Page 123)
# 📄 Fetching page 124/152 for RU
# 💾 Checkpoint saved (Page 124)
# 📄 Fetching page 125/152 for RU
# 💾 Checkpoint saved (Page 125)
# 📄 Fetching page 126/152 for RU
# 💾 Checkpoint saved (Page 126)
# 📄 Fetching page 127/152 for RU
# 💾 Checkpoint saved (Page 127)
# 📄 Fetching page 128/152 for RU
# 💾 Checkpoint saved (Page 128)
# 📄 Fetching page 129/152 for RU
# 💾 Checkpoint saved (Page 129)
# 📄 Fetching page 130/152 for RU
# 💾 Checkpoint saved (Page 130)
# 📄 Fetching page 131/152 for RU
# 💾 Checkpoint saved (Page 131)
# 📄 Fetching page 132/152 for RU
# 💾 Checkpoint saved (Page 132)
# 📄 Fetching page 133/152 for RU
# 💾 Checkpoint saved (Page 133)
# 📄 Fetching page 134/152 for RU
# 💾 Checkpoint saved (Page 134)
# 📄 Fetching page 135/152 for RU
# 💾 Checkpoint saved (Page 135)
# 📄 Fetching page 136/152 for RU
# 💾 Checkpoint saved (Page 136)
# 📄 Fetching page 137/152 for RU
# 💾 Checkpoint saved (Page 137)
# 📄 Fetching page 138/152 for RU
# 💾 Checkpoint saved (Page 138)
# 📄 Fetching page 139/152 for RU
# 💾 Checkpoint saved (Page 139)
# 📄 Fetching page 140/152 for RU
# 💾 Checkpoint saved (Page 140)
# 📄 Fetching page 141/152 for RU
# 💾 Checkpoint saved (Page 141)
# 📄 Fetching page 142/152 for RU
# 💾 Checkpoint saved (Page 142)
# 📄 Fetching page 143/152 for RU
# 💾 Checkpoint saved (Page 143)
# 📄 Fetching page 144/152 for RU
# 💾 Checkpoint saved (Page 144)
# 📄 Fetching page 145/152 for RU
# 💾 Checkpoint saved (Page 145)
# 📄 Fetching page 146/152 for RU
# 💾 Checkpoint saved (Page 146)
# 📄 Fetching page 147/152 for RU
# 💾 Checkpoint saved (Page 147)
# 📄 Fetching page 148/152 for RU
# 💾 Checkpoint saved (Page 148)
# 📄 Fetching page 149/152 for RU
# 💾 Checkpoint saved (Page 149)
# 📄 Fetching page 150/152 for RU
# 💾 Checkpoint saved (Page 150)
# 📄 Fetching page 151/152 for RU
# 💾 Checkpoint saved (Page 151)
# 📄 Fetching page 152/152 for RU
# 💾 Checkpoint saved (Page 152)
# ✅ Final saved at: /content/RU/RU_combined_data.csv
#
# ==================== SM ====================
# ⚠️ No notices found for SM. Skipping...
#
# ==================== RS ====================
# 🔍 19 notices, 1 pages for RS
# 📄 Fetching page 1/1 for RS
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/RS/RS_combined_data.csv
#
# ==================== SK ====================
# 🔍 9 notices, 1 pages for SK
# 📄 Fetching page 1/1 for SK
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/SK/SK_combined_data.csv
#
# ==================== SI ====================
# 🔍 3 notices, 1 pages for SI
# 📄 Fetching page 1/1 for SI
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/SI/SI_combined_data.csv
#
# ==================== ES ====================
# 🔍 8 notices, 1 pages for ES
# 📄 Fetching page 1/1 for ES
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/ES/ES_combined_data.csv
#
# ==================== SE ====================
# 🔍 16 notices, 1 pages for SE
# 📄 Fetching page 1/1 for SE
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/SE/SE_combined_data.csv
#
# ==================== CH ====================
# 🔍 4 notices, 1 pages for CH
# 📄 Fetching page 1/1 for CH
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/CH/CH_combined_data.csv
#
# ==================== TR ====================
# 🔍 25 notices, 2 pages for TR
# 📄 Fetching page 1/2 for TR
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/2 for TR
# 💾 Checkpoint saved (Page 2)
# ✅ Final saved at: /content/TR/TR_combined_data.csv
#
# ==================== UA ====================
# 🔍 51 notices, 3 pages for UA
# 📄 Fetching page 1/3 for UA
# 💾 Checkpoint saved (Page 1)
# 📄 Fetching page 2/3 for UA
# 💾 Checkpoint saved (Page 2)
# 📄 Fetching page 3/3 for UA
# 💾 Checkpoint saved (Page 3)
# ✅ Final saved at: /content/UA/UA_combined_data.csv
#
# ==================== GB ====================
# 🔍 13 notices, 1 pages for GB
# 📄 Fetching page 1/1 for GB
# 💾 Checkpoint saved (Page 1)
# ✅ Final saved at: /content/GB/GB_combined_data.csv
#
# ==================== VA ====================
# ⚠️ No notices found for VA. Skipping...

# %%
import os
import shutil
from google.colab import files

# Step 1: Identify 2-letter country folders
country_folders = [
    f for f in os.listdir("/content")
    if os.path.isdir(os.path.join("/content", f)) and len(f) == 2 and f.isalpha()
]

# Step 2: Create parent folder
parent_folder = f"ALL_COUNTRIES"
parent_path = os.path.join("/content", parent_folder)
os.makedirs(parent_path, exist_ok=True)

# Step 3: Move each 2-letter folder into parent folder
for folder in country_folders:
    src = os.path.join("/content", folder)
    dst = os.path.join(parent_path, folder)
    shutil.move(src, dst)

# Step 4: Zip the parent folder
zip_path = shutil.make_archive(parent_path, 'zip', parent_path)
print(f"📦 Zipped archive created at: {zip_path}")

# Step 5: Download the zip file
files.download(zip_path)
# Out:
# 📦 Zipped archive created at: /content/ALL_COUNTRIES.zip
